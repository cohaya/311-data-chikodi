# %%
import pandas as pd
import altair as alt

# %% [markdown]
# **Import data. Kept getting error messages when using the google drive link to import so just imported it locally**

# %%
sandiego = pd.read_csv("/Users/theresaohaya/Downloads/sandiego.csv")

# %%
sandiego.head()
# Out:
#    service_request_id  service_request_parent_id  sap_notification_number  \
# 0              100763                        NaN             4.030001e+10
# 1              100777                        NaN             4.030001e+10
# 2              100985                        NaN             4.030001e+10
# 3              101169                        NaN             4.030001e+10
# 4              101707                        NaN             4.030000e+10
#
#         date_requested  case_age_days case_record_type           service_name  \
# 0  2016-08-20T14:46:00           3070              TSW        Street Sweeping
# 1  2016-08-20T15:48:00           3070              TSW  Sidewalk Repair Issue
# 2  2016-08-22T10:04:00           3068              TSW             Stormwater
# 3  2016-08-23T08:30:00           3067              TSW   Pavement Maintenance
# 4  2016-08-25T15:01:00           3065              TSW   Pavement Maintenance
#
# ...

# %% [markdown]
# **What service requests are most common?**

# %%
sandiego["service_name"].value_counts()
# Out:
# service_name
# Sidewalk Repair Issue                      13613
# Street Light Maintenance                    9265
# ROW Maintenance                             7287
# Pavement Maintenance                        5116
# Graffiti - Code Enforcement                 3489
# Vegetation Encroachment                     3364
# Parking Violation                           2524
# Encampment                                  2520
# Stormwater                                  2457
# Traffic Sign Maintenance                    2190
# Parks Issue                                 1984
# Development Services - Code Enforcement     1808
# Other                                       1440
# Tree Maintenance                            1329
# Traffic Engineering                         1213
# Illegal Dumping                              972
# Environmental Services Code Compliance       802
# Graffiti - Private                           635
# Missed Collection                            625
# ...

# %%
sandiego["comm_plan_name"].value_counts()
# Out:
# comm_plan_name
# Downtown                             3449
# Uptown                               3390
# North Park                           2847
# Clairemont Mesa                      2829
# Pacific Beach                        2325
#                                      ...
# East Elliott                            5
# NCFUA SUBAREA II                        3
# FAIRBANKS RANCH COUNTRY CLUB            3
# VIA DE LA VALLE                         3
# Reserve Area-Not A Community Plan       2
# Name: count, Length: 115, dtype: int64

# %% [markdown]
# **How are people reporting these issues - through phone app, website, or phone call?**

# %%
sandiego["case_origin"].value_counts()
# Out:
# case_origin
# Mobile                 44375
# Web                    16927
# Phone                   7909
# Email                    410
# GID Field                148
# CC Self Generate         104
# Internal                  49
# Worker App                46
# Self-Generated            44
# Hauler List               17
# Residential Patrol        10
# Crew/Self Generated        4
# Letter                     2
# Walk-In                    1
# Referral Notice            1
# Referral                   1
# FO Self Generate           1
# 999                        1
# Special Events             1
# Famosa Patrol              1
# Name: count, dtype: int64

# %%
sandiego['service_name'].value_counts()
# Out:
# service_name
# Sidewalk Repair Issue                      13613
# Street Light Maintenance                    9265
# ROW Maintenance                             7287
# Pavement Maintenance                        5116
# Graffiti - Code Enforcement                 3489
# Vegetation Encroachment                     3364
# Parking Violation                           2524
# Encampment                                  2520
# Stormwater                                  2457
# Traffic Sign Maintenance                    2190
# Parks Issue                                 1984
# Development Services - Code Enforcement     1808
# Other                                       1440
# Tree Maintenance                            1329
# Traffic Engineering                         1213
# Illegal Dumping                              972
# Environmental Services Code Compliance       802
# Graffiti - Private                           635
# Missed Collection                            625
# ...

# %% [markdown]
# **How many requests are from each council district?**

# %%
sandiego['council_district'].value_counts()
# Out:
# council_district
# 3.0    15922
# 2.0     9579
# 9.0     8980
# 1.0     7956
# 8.0     5366
# 7.0     4927
# 4.0     4332
# 5.0     4250
# 6.0     4034
# Name: count, dtype: int64

# %% [markdown]
# **Changing the dates to a workable format and then getting just the years**

# %%
sandiego['date_requested'] = pd.to_datetime(sandiego['date_requested']).dt.date

# %%
sandiego['date_closed'] = pd.to_datetime(sandiego['date_closed']).dt.date

# %%
pd.to_datetime(sandiego['date_requested']).dt.year
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 70065    2016
# 70066    2016
# 70067    2016
# 70068    2016
# 70069    2016
# Name: date_requested, Length: 70070, dtype: int32

# %%
sandiego['year'] = pd.to_datetime(sandiego['date_requested']).dt.year

# %%
sandiego.head()
# Out:
#    service_request_id  service_request_parent_id  sap_notification_number  \
# 0              100763                        NaN             4.030001e+10
# 1              100777                        NaN             4.030001e+10
# 2              100985                        NaN             4.030001e+10
# 3              101169                        NaN             4.030001e+10
# 4              101707                        NaN             4.030000e+10
#
#   date_requested  case_age_days case_record_type           service_name  \
# 0     2016-08-20           3070              TSW        Street Sweeping
# 1     2016-08-20           3070              TSW  Sidewalk Repair Issue
# 2     2016-08-22           3068              TSW             Stormwater
# 3     2016-08-23           3067              TSW   Pavement Maintenance
# 4     2016-08-25           3065              TSW   Pavement Maintenance
#
#              service_name_detail date_closed      status  ...  \
# ...

# %% [markdown]
# **What year has the most open requests?**

# %%
sandiego['year'].value_counts()
# Out:
# year
# 2024    26788
# 2023    13822
# 2022     8063
# 2018     5748
# 2025     5242
# 2021     4594
# 2020     2832
# 2019     1924
# 2017      925
# 2016      132
# Name: count, dtype: int64

# %% [markdown]
# Saving changes to file

# %%
sandiego.to_csv('San Diego 311 Requests.csv',index=False)

# %% [markdown]
# **Reading in population data to try to see how many requests per person in each district. Does district 3 just have the most requests because it has the most people?**

# %%
population = pd.read_csv("/Users/theresaohaya/Downloads/populationsd.csv")

# %%
population.head()
# Out:
#    sdcouncil  yr_id                  long_name  population
# 0        NaN   2010       Household Population     1737901
# 1        NaN   2010  Group Quarters - Military       29136
# 2        NaN   2010   Group Quarters - College         757
# 3        NaN   2010     Group Quarters - Other       25902
# 4        NaN   2011       Household Population     1759954

# %% [markdown]
# **Filtering the population data for total population since we don't care about college, military, or other breakdowns.**

# %%
district_populations = 'Household Population'

# %%
household_population = population[population['long_name']==district_populations]

# %% [markdown]
# **Filtering the population data for just the most recent year in the data set which is 2021**

# %%
final_year = 2021

# %%
final_population = household_population[household_population['yr_id']==final_year]

# %%
final_population.value_counts()
# Out:
# sdcouncil  yr_id  long_name             population
# 1.0        2021   Household Population  161394        1
# 2.0        2021   Household Population  153544        1
# 3.0        2021   Household Population  198555        1
# 4.0        2021   Household Population  126873        1
# 5.0        2021   Household Population  154900        1
# 6.0        2021   Household Population  140195        1
# 7.0        2021   Household Population  159828        1
# 8.0        2021   Household Population  129935        1
# 9.0        2021   Household Population  139579        1
# Name: count, dtype: int64

# %% [markdown]
# **Save filtered population data**

# %%
final_population.to_csv("San Diego Council District Populations.csv",index=False)

# %% [markdown]
# **Renaming columns to match the request dataset**

# %%
bad_columns = {'yr_id':'year',
               'population':'council district population',
               'sdcouncil':'council_district'
               }

# %%
final_population = final_population.rename(columns=bad_columns)

# %%
final_population.head()
# Out:
#      council_district  year             long_name  council district population
# 44                NaN  2021  Household Population                      1854255
# 92                1.0  2021  Household Population                       161394
# 140               2.0  2021  Household Population                       153544
# 188               3.0  2021  Household Population                       198555
# 236               4.0  2021  Household Population                       126873

# %%
final_population.to_csv("San Diego Council District Populations.csv",index=False)

# %% [markdown]
# **Merging population data and request data**

# %%
merged_list = pd.merge(sandiego, final_population, on=['council_district','year'])

# %%
calls = 'Phone'

# %%
sandiego[sandiego['case_origin']==calls]
# Out:
#        service_request_id  service_request_parent_id  sap_notification_number  \
# 2                  100985                        NaN             4.030001e+10
# 13                 104559                        NaN             4.030001e+10
# 15                 106563                        NaN             4.030000e+10
# 17                 107101                        NaN             4.030001e+10
# 19                 107423                        NaN             4.030001e+10
# ...                   ...                        ...                      ...
# 70031               82982                        NaN             4.030003e+10
# 70032               83413                        NaN             4.030003e+10
# 70038               87037                        NaN             4.030001e+10
# 70042               88977                        NaN             4.030000e+10
# 70061               96129                        NaN             4.030001e+10
#
# ...

# %% [markdown]
# **I found out that not all of the cells in the data had information about the council districts that they came from. Those aren't important to me at this point since I'm trying to figure out which council districts had the most requests per person. I'm trying to filter those empty rows out**

# %%
empty = ''

# %%
sandiego[sandiego['council_district']==empty]
# Out:
# Empty DataFrame
# Columns: [service_request_id, service_request_parent_id, sap_notification_number, date_requested, case_age_days, case_record_type, service_name, service_name_detail, date_closed, status, lat, lng, street_address, zipcode, council_district, comm_plan_code, comm_plan_name, park_name, case_origin, referred, iamfloc, floc, public_description, year]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# **Okay so you can't filter by just empty cells because python has a different code for that which is .isna()**

# %%
empty_council = sandiego[sandiego['council_district'].isna()]

# %%
merged_list
# Out:
#       service_request_id  service_request_parent_id  sap_notification_number  \
# 0                3190635                  3190636.0                      NaN
# 1                3190636                  3190635.0                      NaN
# 2                3190753                        NaN             4.030037e+10
# 3                3190897                  2440727.0                      NaN
# 4                3190961                        NaN             4.030037e+10
# ...                  ...                        ...                      ...
# 4589             3620415                        NaN             4.030049e+10
# 4590             3620596                        NaN             4.030050e+10
# 4591             3620604                        NaN             4.030050e+10
# 4592             3620609                  3620604.0                      NaN
# 4593             3620682                  3601380.0                      NaN
#
# ...

# %%
sandiego
# Out:
#        service_request_id  service_request_parent_id  sap_notification_number  \
# 0                  100763                        NaN             4.030001e+10
# 1                  100777                        NaN             4.030001e+10
# 2                  100985                        NaN             4.030001e+10
# 3                  101169                        NaN             4.030001e+10
# 4                  101707                        NaN             4.030000e+10
# ...                   ...                        ...                      ...
# 70065               96860                        NaN             4.030001e+10
# 70066               97713                        NaN             4.030001e+10
# 70067               98608                        NaN             4.030001e+10
# 70068               98792                    91703.0                      NaN
# 70069               99646                        NaN             4.030000e+10
#
# ...

# %%
merged_list.head()
# Out:
#    service_request_id  service_request_parent_id  sap_notification_number  \
# 0             3190635                  3190636.0                      NaN
# 1             3190636                  3190635.0                      NaN
# 2             3190753                        NaN             4.030037e+10
# 3             3190897                  2440727.0                      NaN
# 4             3190961                        NaN             4.030037e+10
#
#   date_requested  case_age_days case_record_type           service_name  \
# 0     2021-01-01           1475              TSW      Graffiti - Public
# 1     2021-01-01           1475              TSW      Graffiti - Public
# 2     2021-01-01           1475              TSW   Pavement Maintenance
# 3     2021-01-01           1475              TSW  Sidewalk Repair Issue
# 4     2021-01-01           1475              TSW             Stormwater
#
#               service_name_detail date_closed      status  ...  \
# ...

# %% [markdown]
# **Ooop, merging just based on council district. Not year**

# %%
merged_list = pd.merge(sandiego, final_population, on=['council_district'])

# %%
merged_list
# Out:
#        service_request_id  service_request_parent_id  sap_notification_number  \
# 0                  100763                        NaN             4.030001e+10
# 1                  100777                        NaN             4.030001e+10
# 2                  100985                        NaN             4.030001e+10
# 3                  101169                        NaN             4.030001e+10
# 4                  101707                        NaN             4.030000e+10
# ...                   ...                        ...                      ...
# 70065               96860                        NaN             4.030001e+10
# 70066               97713                        NaN             4.030001e+10
# 70067               98608                        NaN             4.030001e+10
# 70068               98792                    91703.0                      NaN
# 70069               99646                        NaN             4.030000e+10
#
# ...

# %%
final_population.head(
)
# Out:
#      council_district  year             long_name  council district population
# 44                NaN  2021  Household Population                      1854255
# 92                1.0  2021  Household Population                       161394
# 140               2.0  2021  Household Population                       153544
# 188               3.0  2021  Household Population                       198555
# 236               4.0  2021  Household Population                       126873

# %% [markdown]
# **Dropping the year column from the population dataset. Since we know that it's 2021, we don't need to add another column to the request data**

# %%
final_population.drop(columns=['year'],inplace=True)

# %% [markdown]
# **Merging again. Third time's the charm**

# %%
merged_list = pd.merge(sandiego, final_population, on=['council_district'])

# %%
merged_list
# Out:
#        service_request_id  service_request_parent_id  sap_notification_number  \
# 0                  100763                        NaN             4.030001e+10
# 1                  100777                        NaN             4.030001e+10
# 2                  100985                        NaN             4.030001e+10
# 3                  101169                        NaN             4.030001e+10
# 4                  101707                        NaN             4.030000e+10
# ...                   ...                        ...                      ...
# 70065               96860                        NaN             4.030001e+10
# 70066               97713                        NaN             4.030001e+10
# 70067               98608                        NaN             4.030001e+10
# 70068               98792                    91703.0                      NaN
# 70069               99646                        NaN             4.030000e+10
#
# ...

# %% [markdown]
# **Looking at counts for council districts and making that a separate index**

# %%
district_counts = merged_list['council_district'].value_counts()

# %%
district_counts.reset_index().sort_values('council_district')
# Out:
#    council_district  count
# 3               1.0   7956
# 1               2.0   9579
# 0               3.0  15922
# 6               4.0   4332
# 7               5.0   4250
# 8               6.0   4034
# 5               7.0   4927
# 4               8.0   5366
# 2               9.0   8980

# %% [markdown]
# **Hmm it might be easier to merge the just the district counts and the population data**

# %%
merged_districts = pd.merge(district_counts, final_population, on='council_district')

# %%
merged_districts.head()
# Out:
#    council_district  count             long_name  council district population
# 0               3.0  15922  Household Population                       198555
# 1               2.0   9579  Household Population                       153544
# 2               9.0   8980  Household Population                       139579
# 3               1.0   7956  Household Population                       161394
# 4               8.0   5366  Household Population                       129935

# %%
merged_districts = merged_districts.reset_index()

# %%
merged_districts
# Out:
#    index  council_district  count             long_name  \
# 0      0               3.0  15922  Household Population
# 1      1               2.0   9579  Household Population
# 2      2               9.0   8980  Household Population
# 3      3               1.0   7956  Household Population
# 4      4               8.0   5366  Household Population
# 5      5               7.0   4927  Household Population
# 6      6               4.0   4332  Household Population
# 7      7               5.0   4250  Household Population
# 8      8               6.0   4034  Household Population
#
#    council district population
# 0                       198555
# 1                       153544
# 2                       139579
# 3                       161394
# 4                       129935
# 5                       159828
# 6                       126873
# 7                       154900
# 8                       140195

# %% [markdown]
# **Looking at the number of reports per capita aka per person**

# %%
merged_districts['reports per capita'] = merged_districts['count']/merged_districts['council district population']

# %%
merged_districts
# Out:
#    index  council_district  count             long_name  \
# 0      0               3.0  15922  Household Population
# 1      1               2.0   9579  Household Population
# 2      2               9.0   8980  Household Population
# 3      3               1.0   7956  Household Population
# 4      4               8.0   5366  Household Population
# 5      5               7.0   4927  Household Population
# 6      6               4.0   4332  Household Population
# 7      7               5.0   4250  Household Population
# 8      8               6.0   4034  Household Population
#
#    council district population  reports per capita
# 0                       198555            0.080189
# 1                       153544            0.062386
# 2                       139579            0.064336
# 3                       161394            0.049296
# 4                       129935            0.041298
# 5                       159828            0.030827
# ...

# %% [markdown]
# **Okay so the fractions are really small. .08 reports per person doesn't mean anything to a normal person so I'll look at reports per 1000 people instead**

# %%
merged_districts['reports per capita']*1000
# Out:
# 0    80.189368
# 1    62.386026
# 2    64.336326
# 3    49.295513
# 4    41.297572
# 5    30.826889
# 6    34.144381
# 7    27.437056
# 8    28.774207
# Name: reports per capita, dtype: float64

# %%
merged_districts['per 1000 residents'] = merged_districts['reports per capita']*1000

# %%
merged_districts
# Out:
#    index  council_district  count             long_name  \
# 0      0               3.0  15922  Household Population
# 1      1               2.0   9579  Household Population
# 2      2               9.0   8980  Household Population
# 3      3               1.0   7956  Household Population
# 4      4               8.0   5366  Household Population
# 5      5               7.0   4927  Household Population
# 6      6               4.0   4332  Household Population
# 7      7               5.0   4250  Household Population
# 8      8               6.0   4034  Household Population
#
#    council district population  reports per capita  per 1000 residents
# 0                       198555            0.080189           80.189368
# 1                       153544            0.062386           62.386026
# 2                       139579            0.064336           64.336326
# 3                       161394            0.049296           49.295513
# ...

# %% [markdown]
# **Okay let's make a chart. I'm still not sure how to sort the data by districts. I tried doing that but got an error**

# %%
alt.Chart(merged_districts).mark_circle().encode(
    size = 'per 1000 residents',
    y=alt.Y('council_district').sort('-size'),
    tooltip='per 1000 residents',
).properties(
    title='San Diego 311 Reports by Council District'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# This is to read in the new data we got for San Diego for all the cases

# %%
newdata = pd.read_csv('/Users/theresaohaya/Downloads/newdatasd.csv')
# Out:
# /var/folders/rb/lmsn3t4135n_jby_23tg2ry40000gn/T/ipykernel_69680/2683967761.py:1: DtypeWarning: Columns (8,19,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   newdata = pd.read_csv('/Users/theresaohaya/Downloads/newdatasd.csv')

# %%
newdata.head()
# Out:
#    service_request_id  service_request_parent_id  sap_notification_number  \
# 0              100258                        NaN             4.030001e+10
# 1              101166                        NaN             4.030000e+10
# 2              102962                        NaN             4.030001e+10
# 3              107370                   101166.0                      NaN
# 4              113334                        NaN             4.030001e+10
#
#         date_requested  case_age_days case_record_type           service_name  \
# 0  2016-08-18T10:02:00         2056.0              TSW   Pavement Maintenance
# 1  2016-08-23T08:19:00         2267.0              TSW  Sidewalk Repair Issue
# 2  2016-09-01T15:13:00         2177.0              TSW  Sidewalk Repair Issue
# 3  2016-09-22T09:39:00         2237.0              TSW  Sidewalk Repair Issue
# 4  2016-10-21T13:40:00         2119.0              TSW  Sidewalk Repair Issue
#
# ...

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259452 entries, 0 to 1259451
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   service_request_id         1259452 non-null  int64
#  1   service_request_parent_id  197474 non-null   float64
#  2   sap_notification_number    174072 non-null   float64
#  3   date_requested             1259452 non-null  object
#  4   case_age_days              1259452 non-null  float64
#  5   case_record_type           1259452 non-null  object
#  6   service_name               1259286 non-null  object
#  7   service_name_detail        772972 non-null   object
#  8   date_closed                1210779 non-null  object
#  9   status                     1259452 non-null  object
#  10  lat                        1206060 non-null  float64
#  11  lng                        1206060 non-null  float64
# ...

# %% [markdown]
# **How many requests are there?**

# %%
len(newdata)
# Out:
# 1259452

# %% [markdown]
# **What are the major categories for service requests?**

# %%
newdata['case_record_type'].value_counts()
# Out:
# case_record_type
# ESD Complaint/Report            426862
# TSW                             397181
# Parking                         183595
# Neighborhood Policing           160279
# Parks & Recreation               32043
# TSW ROW                          27853
# DSD                              11302
# Storm Water Code Enforcement     10893
# Traffic Engineering               9444
# Name: count, dtype: int64

# %% [markdown]
# **This is to convert the dates into a workable format**

# %%
newdata['date_requested'] = pd.to_datetime(newdata['date_requested'], format='mixed').dt.date

# %%
newdata['year'] = pd.to_datetime(newdata['date_requested']).dt.year

# %% [markdown]
# **Finding out what years have the most requests**

# %%
newdata['year'].value_counts()
# Out:
# year
# 2023    435876
# 2024    418727
# 2022    364965
# 2021     30597
# 2020      6232
# 2019      1509
# 2018       749
# 2017       638
# 2016       159
# Name: count, dtype: int64

# %% [markdown]
# **What service requests are most common?**

# %%
newdata['service_name'].value_counts()
# Out:
# service_name
# Illegal Dumping                            209267
# Encampment                                 187921
# Missed Collection                          129312
# Parking Violation                           96980
# Parking                                     86628
# Graffiti - Public                           80194
# Pothole                                     60791
# Street Light Maintenance                    37789
# Graffiti - Code Enforcement                 34147
# Other                                       31841
# Parks Issue                                 24444
# Sidewalk Repair Issue                       23282
# Environmental Services Code Compliance      21976
# Tree Maintenance                            21813
# ROW Maintenance                             21164
# Graffiti                                    19789
# Traffic Signal Issue                        18116
# Traffic Sign Maintenance                    17880
# ...

# %% [markdown]
# **Hmm it's weird that there's both "Parking" and "Parking Violation" as service requests. I wonder what all the data that contains the word "Parking" look like**

# %%
parking = newdata[newdata['service_name'].str.contains('Parking', case=False, na=False)]

# %%
parking
# Out:
#          service_request_id  service_request_parent_id  \
# 1342                2935270                        NaN
# 1483                2950324                        NaN
# 2096                3011438                  2935270.0
# 2371                3040437                        NaN
# 2431                3045580                        NaN
# ...                     ...                        ...
# 1259116             5055494                        NaN
# 1259119             3678628                        NaN
# 1259448             4874126                        NaN
# 1259449             4882828                        NaN
# 1259451             5045204                        NaN
#
#          sap_notification_number date_requested  case_age_days  \
# 1342                         NaN     2020-04-18          676.0
# 1483                         NaN     2020-05-07          656.0
# 2096                         NaN     2020-07-14          617.0
# ...

# %%
parking['service_name_detail'].value_counts()
# Out:
# service_name_detail
# 72 Hour Violation         123662
# Parking Zone Violation     13610
# Red Zone                    7525
# Sidewalk                    5026
# Alley                       4235
# Lane of Traffic             3585
# No Residential Permit       1888
# Green/Time Limited          1734
# Blue Disabled Zone          1319
# Bike Lane                   1284
# Fire Hydrant                1150
# Passenger Zone (White)      1096
# Yellow Commercial Zone       700
# Timed Zone Violation          78
# Parking                       26
# AVA                           23
# Citizen Contact                4
# Parking Meter                  2
# Name: count, dtype: int64

# %% [markdown]
# **Okay based on this I think it's safe to just rename all "parking violation" requests to "parking"**

# %%
newdata['service_name'] = newdata['service_name'].replace('Parking Violation', 'Parking')

# %% [markdown]
# **Let's make sure this worked by rerunning "service name"**

# %%
newdata['service_name'].value_counts()
# Out:
# service_name
# Illegal Dumping                            209267
# Encampment                                 187921
# Parking                                    183608
# Missed Collection                          129312
# Graffiti - Public                           80194
# Pothole                                     60791
# Street Light Maintenance                    37789
# Graffiti - Code Enforcement                 34147
# Other                                       31841
# Parks Issue                                 24444
# Sidewalk Repair Issue                       23282
# Environmental Services Code Compliance      21976
# Tree Maintenance                            21813
# ROW Maintenance                             21164
# Graffiti                                    19789
# Traffic Signal Issue                        18116
# Traffic Sign Maintenance                    17880
# Shared Mobility Device                      17064
# ...

# %% [markdown]
# **Okay so I noticed the same thing with graffiti. There are 3 different categories for graffiti. Let's see if those are substantially different**

# %%
newdata['service_name'] = newdata['service_name'].replace('Parking Violation', 'Parking')

# %%
graffiti = newdata[newdata['service_name'].str.contains('Graffiti', case=False, na=False)]

# %%
graffiti
# Out:
#          service_request_id  service_request_parent_id  \
# 1039                2889466                  2888263.0
# 3189                3106965                        NaN
# 4529                3183925                        NaN
# 4641                3192556                        NaN
# 4681                3194529                        NaN
# ...                     ...                        ...
# 1259108             5054754                        NaN
# 1259112             5055392                        NaN
# 1259113             5055409                        NaN
# 1259117             5055621                        NaN
# 1259450             5041092                        NaN
#
#          sap_notification_number date_requested  case_age_days  \
# 1039                         NaN     2020-02-20          719.0
# 3189                         NaN     2020-10-10          472.0
# 4529                         NaN     2020-12-25          447.0
# ...

# %% [markdown]
# **It doesn't look like the different categories for graffiti mean much. Going to make those into a single category for service requests**

# %%
newdata['service_name'] = newdata['service_name'].replace('Graffiti - Public', 'Graffiti')

# %%
newdata['service_name'] = newdata['service_name'].replace('Graffiti - Code Enforcement', 'Graffiti')

# %%
newdata['service_name'].value_counts()
# Out:
# service_name
# Illegal Dumping                            209267
# Encampment                                 187921
# Parking                                    183608
# Graffiti                                   134130
# Missed Collection                          129312
# Pothole                                     60791
# Street Light Maintenance                    37789
# Other                                       31841
# Parks Issue                                 24444
# Sidewalk Repair Issue                       23282
# Environmental Services Code Compliance      21976
# Tree Maintenance                            21813
# ROW Maintenance                             21164
# Traffic Signal Issue                        18116
# Traffic Sign Maintenance                    17880
# Shared Mobility Device                      17064
# Dead Animal                                 13100
# Traffic Signal Timing                       12834
# ...

# %% [markdown]
# **Okay so now we have 5 types of service requests that each have more than 100,000 requests. I think that's where I'll focus my analysis moving forward**
